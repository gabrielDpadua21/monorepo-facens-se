# %% [markdown]
# # Exercicio - Seleção de Variáveis

# %% [markdown]
# - Gabriel D. Padua RA: 200749
# - Rafael Prestes RA 200779
# - Thomas Elinton RA 130531

# %%
hbat <- read.csv(file = '../../../data/HBAT.csv')
head(hbat)
# Out:
#   X id x1               x2                 x3
# 1 1 1  1 to 5 years     Magazine industry  Large (500+)
# 2 2 2  Over 5 years     Newsprint industry Small (0 to 499)
# 3 3 3  Over 5 years     Magazine industry  Large (500+)
# 4 4 4  Less than 1 year Newsprint industry Large (500+)
# 5 5 5  1 to 5 years     Magazine industry  Large (500+)
# 6 6 6  Less than 1 year Newsprint industry Small (0 to 499)
#   x4                    x5                      x6  x7  x8  ⋯ x14 x15 x16 x17
# 1 Outside North America Direct to customer      8.5 3.9 2.5 ⋯ 4.7 4.3 5.0 5.1
# 2 USA/North America     Indirect through broker 8.2 2.7 5.1 ⋯ 5.5 4.0 3.9 4.3
# 3 Outside North America Direct to customer      9.2 3.4 5.6 ⋯ 6.2 4.6 5.4 4.0
# 4 Outside North America Indirect through broker 6.4 3.3 7.0 ⋯ 7.0 3.6 4.3 4.1
# 5 USA/North America     Direct to customer      9.0 3.4 5.2 ⋯ 6.1 4.5 4.5 3.5
# 6 Outside North America Indirect through broker 6.5 2.8 3.1 ⋯ 5.1 9.5 3.6 4.7
#   x18 x19 x20 x21 x22  x23
# 1 3.7 8.2 8.0 8.4 65.1 Yes, would consider
# 2 4.9 5.7 6.5 7.5 67.1 No, would not consider
# 3 4.5 8.9 8.4 9.0 72.1 Yes, would consider
# 4 3.0 4.8 6.0 7.2 40.1 No, would not consider
# 5 3.5 7.1 6.6 9.0 57.1 No, would not consider
# 6 3.3 4.7 6.3 6.1 50.1 No, would not consider

# %%
View(hbat)
# Out:
#     X   id  x1               x2                 x3
# 1    1   1  1 to 5 years     Magazine industry  Large (500+)
# 2    2   2  Over 5 years     Newsprint industry Small (0 to 499)
# 3    3   3  Over 5 years     Magazine industry  Large (500+)
# 4    4   4  Less than 1 year Newsprint industry Large (500+)
# 5    5   5  1 to 5 years     Magazine industry  Large (500+)
# 6    6   6  Less than 1 year Newsprint industry Small (0 to 499)
# 7    7   7  Less than 1 year Newsprint industry Large (500+)
# 8    8   8  1 to 5 years     Magazine industry  Large (500+)
# 9    9   9  1 to 5 years     Newsprint industry Large (500+)
# 10  10  10  Less than 1 year Magazine industry  Large (500+)
# 11  11  11  Over 5 years     Magazine industry  Large (500+)
# 12  12  12  Less than 1 year Magazine industry  Large (500+)
# 13  13  13  Less than 1 year Newsprint industry Small (0 to 499)
# 14  14  14  Over 5 years     Newsprint industry Small (0 to 499)
# 15  15  15  1 to 5 years     Magazine industry  Large (500+)
# 16  16  16  Over 5 years     Magazine industry  Small (0 to 499)
# 17  17  17  1 to 5 years     Newsprint industry Small (0 to 499)
# 18  18  18  1 to 5 years     Magazine industry  Large (500+)
# 19  19  19  1 to 5 years     Newsprint industry Large (500+)
# 20  20  20  Over 5 years     Magazine industry  Large (500+)
# 21  21  21  Less than 1 year Magazine industry  Small (0 to 499)
# 22  22  22  Over 5 years     Newsprint industry Large (500+)
# 23  23  23  1 to 5 years     Magazine industry  Small (0 to 499)
# 24  24  24  Over 5 years     Magazine industry  Large (500+)
# 25  25  25  Less than 1 year Magazine industry  Small (0 to 499)
# 26  26  26  1 to 5 years     Magazine industry  Large (500+)
# 27  27  27  Over 5 years     Magazine industry  Small (0 to 499)
# 28  28  28  Less than 1 year Newsprint industry Small (0 to 499)
# 29  29  29  Over 5 years     Magazine industry  Small (0 to 499)
# 30  30  30  Less than 1 year Newsprint industry Large (500+)
# ⋮   ⋮   ⋮   ⋮                ⋮                  ⋮
# 71   71  71 Over 5 years     Magazine industry  Small (0 to 499)
# 72   72  72 Less than 1 year Newsprint industry Small (0 to 499)
# 73   73  73 1 to 5 years     Magazine industry  Large (500+)
# 74   74  74 Over 5 years     Magazine industry  Large (500+)
# 75   75  75 1 to 5 years     Magazine industry  Large (500+)
# 76   76  76 Over 5 years     Magazine industry  Small (0 to 499)
# 77   77  77 Less than 1 year Magazine industry  Small (0 to 499)
# 78   78  78 1 to 5 years     Newsprint industry Small (0 to 499)
# 79   79  79 Over 5 years     Magazine industry  Small (0 to 499)
# 80   80  80 Less than 1 year Newsprint industry Large (500+)
# 81   81  81 Over 5 years     Magazine industry  Large (500+)
# 82   82  82 Over 5 years     Magazine industry  Small (0 to 499)
# 83   83  83 1 to 5 years     Magazine industry  Small (0 to 499)
# 84   84  84 Less than 1 year Newsprint industry Small (0 to 499)
# 85   85  85 1 to 5 years     Magazine industry  Small (0 to 499)
# 86   86  86 Less than 1 year Newsprint industry Large (500+)
# 87   87  87 Less than 1 year Magazine industry  Small (0 to 499)
# 88   88  88 1 to 5 years     Magazine industry  Small (0 to 499)
# 89   89  89 1 to 5 years     Newsprint industry Small (0 to 499)
# 90   90  90 1 to 5 years     Newsprint industry Small (0 to 499)
# 91   91  91 Over 5 years     Newsprint industry Small (0 to 499)
# 92   92  92 Less than 1 year Newsprint industry Small (0 to 499)
# 93   93  93 Over 5 years     Newsprint industry Large (500+)
# 94   94  94 Over 5 years     Magazine industry  Large (500+)
# 95   95  95 Over 5 years     Newsprint industry Large (500+)
# 96   96  96 Less than 1 year Newsprint industry Small (0 to 499)
# 97   97  97 Less than 1 year Magazine industry  Small (0 to 499)
# 98   98  98 Less than 1 year Magazine industry  Small (0 to 499)
# 99   99  99 1 to 5 years     Newsprint industry Small (0 to 499)
# 100 100 100 1 to 5 years     Newsprint industry Large (500+)
#     x4                    x5                      x6  x7  x8  ⋯ x14 x15 x16 x17
# 1   Outside North America Direct to customer      8.5 3.9 2.5 ⋯ 4.7 4.3 5.0 5.1
# 2   USA/North America     Indirect through broker 8.2 2.7 5.1 ⋯ 5.5 4.0 3.9 4.3
# 3   Outside North America Direct to customer      9.2 3.4 5.6 ⋯ 6.2 4.6 5.4 4.0
# 4   Outside North America Indirect through broker 6.4 3.3 7.0 ⋯ 7.0 3.6 4.3 4.1
# 5   USA/North America     Direct to customer      9.0 3.4 5.2 ⋯ 6.1 4.5 4.5 3.5
# 6   Outside North America Indirect through broker 6.5 2.8 3.1 ⋯ 5.1 9.5 3.6 4.7
# 7   Outside North America Indirect through broker 6.9 3.7 5.0 ⋯ 4.8 2.5 2.1 4.2
# 8   Outside North America Indirect through broker 6.2 3.3 3.9 ⋯ 5.4 4.8 4.3 6.3
# 9   Outside North America Indirect through broker 5.8 3.6 5.1 ⋯ 5.9 4.4 4.4 6.1
# 10  Outside North America Indirect through broker 6.4 4.5 5.1 ⋯ 5.4 5.3 4.1 5.8
# 11  USA/North America     Direct to customer      8.7 3.2 4.6 ⋯ 5.8 7.5 3.8 3.7
# 12  Outside North America Indirect through broker 6.1 4.9 6.3 ⋯ 5.8 5.9 3.0 4.9
# 13  USA/North America     Direct to customer      9.5 5.6 4.6 ⋯ 6.5 5.3 5.1 4.5
# 14  USA/North America     Direct to customer      9.2 3.9 5.7 ⋯ 6.7 3.0 4.5 2.6
# 15  Outside North America Direct to customer      6.3 4.5 4.7 ⋯ 6.0 5.4 4.8 6.2
# 16  USA/North America     Indirect through broker 8.7 3.2 4.0 ⋯ 6.1 5.0 4.3 3.9
# 17  Outside North America Direct to customer      5.7 4.0 6.7 ⋯ 6.7 5.4 4.2 6.2
# 18  Outside North America Indirect through broker 5.9 4.1 5.5 ⋯ 6.2 6.3 5.7 5.8
# 19  Outside North America Indirect through broker 5.6 3.4 5.1 ⋯ 5.4 6.1 5.0 6.0
# 20  Outside North America Indirect through broker 9.1 4.5 3.6 ⋯ 5.8 6.7 4.5 6.1
# 21  Outside North America Indirect through broker 5.2 3.8 7.1 ⋯ 7.1 4.6 3.3 4.9
# 22  Outside North America Direct to customer      9.6 5.7 6.8 ⋯ 6.4 6.5 4.3 3.0
# 23  USA/North America     Direct to customer      8.6 3.6 7.4 ⋯ 6.7 6.0 4.8 3.4
# 24  Outside North America Direct to customer      9.3 2.4 2.6 ⋯ 6.4 4.2 6.7 4.4
# 25  Outside North America Indirect through broker 6.0 4.1 5.3 ⋯ 6.5 3.9 4.7 5.3
# 26  Outside North America Indirect through broker 6.4 3.6 6.6 ⋯ 6.1 3.7 5.6 6.6
# 27  USA/North America     Indirect through broker 8.5 3.0 7.2 ⋯ 6.9 6.7 5.3 3.8
# 28  Outside North America Indirect through broker 7.0 3.3 5.4 ⋯ 6.5 5.9 4.3 5.2
# 29  USA/North America     Indirect through broker 8.5 3.0 5.7 ⋯ 5.8 6.0 5.7 3.8
# 30  Outside North America Indirect through broker 7.6 3.6 3.0 ⋯ 4.9 7.2 4.7 5.5
# ⋮   ⋮                     ⋮                       ⋮   ⋮   ⋮   ⋱ ⋮   ⋮   ⋮   ⋮
# 71  Outside North America Indirect through broker 9.1 4.5 6.1 ⋯ 7.1 5.7 5.4 6.1
# 72  USA/North America     Direct to customer      6.7 3.2 3.0 ⋯ 5.2 2.5 2.9 2.6
# 73  Outside North America Indirect through broker 6.5 4.3 2.7 ⋯ 4.7 6.3 4.6 5.6
# 74  Outside North America Direct to customer      9.9 3.7 7.5 ⋯ 7.2 4.6 4.1 3.4
# 75  Outside North America Direct to customer      8.5 3.9 5.3 ⋯ 5.7 3.6 4.4 5.1
# 76  USA/North America     Indirect through broker 9.9 3.0 6.8 ⋯ 7.3 7.6 3.1 4.3
# 77  Outside North America Direct to customer      7.6 3.6 7.6 ⋯ 8.1 6.6 4.5 5.8
# 78  USA/North America     Direct to customer      9.4 3.8 7.0 ⋯ 7.3 2.4 4.3 4.5
# 79  USA/North America     Direct to customer      9.3 3.5 6.3 ⋯ 6.6 3.1 5.2 4.1
# 80  Outside North America Indirect through broker 7.1 3.4 4.9 ⋯ 6.1 3.5 2.6 3.1
# 81  USA/North America     Indirect through broker 9.9 3.0 7.4 ⋯ 5.9 6.9 3.2 4.3
# 82  USA/North America     Indirect through broker 8.7 3.2 6.4 ⋯ 6.3 5.1 4.3 3.7
# 83  USA/North America     Direct to customer      8.6 2.9 5.8 ⋯ 6.1 4.0 2.7 3.0
# 84  Outside North America Indirect through broker 6.4 3.2 6.7 ⋯ 7.3 6.5 2.0 3.7
# 85  USA/North America     Direct to customer      7.7 2.6 6.7 ⋯ 6.5 4.1 4.7 3.9
# 86  Outside North America Indirect through broker 7.5 3.5 4.1 ⋯ 4.9 2.8 3.4 5.4
# 87  Outside North America Indirect through broker 5.0 3.6 1.3 ⋯ 4.3 7.6 2.4 4.8
# 88  USA/North America     Direct to customer      7.7 2.6 8.0 ⋯ 6.9 7.7 5.1 3.9
# 89  USA/North America     Direct to customer      9.1 3.6 5.5 ⋯ 6.5 4.1 4.6 4.3
# 90  Outside North America Direct to customer      5.5 5.5 7.7 ⋯ 7.4 4.9 5.5 6.7
# 91  USA/North America     Indirect through broker 9.1 3.7 7.0 ⋯ 7.5 4.6 4.4 3.0
# 92  Outside North America Indirect through broker 7.1 4.2 4.1 ⋯ 5.5 3.5 2.0 4.0
# 93  USA/North America     Direct to customer      9.2 3.9 4.6 ⋯ 6.2 6.6 4.4 2.6
# 94  Outside North America Direct to customer      9.3 3.5 5.4 ⋯ 6.4 4.9 4.8 4.1
# 95  USA/North America     Indirect through broker 9.3 3.8 4.0 ⋯ 5.3 4.8 3.6 3.2
# 96  USA/North America     Direct to customer      8.6 4.8 5.6 ⋯ 5.8 3.6 4.9 3.6
# 97  Outside North America Direct to customer      7.4 3.4 2.6 ⋯ 4.5 6.4 4.2 5.6
# 98  USA/North America     Direct to customer      8.7 3.2 3.3 ⋯ 5.0 4.3 3.1 2.9
# 99  Outside North America Direct to customer      7.8 4.9 5.8 ⋯ 6.0 5.7 4.3 4.9
# 100 Outside North America Indirect through broker 7.9 3.0 4.4 ⋯ 5.7 5.8 3.4 5.4
#     x18 x19 x20 x21 x22  x23
# 1   3.7 8.2 8.0 8.4 65.1 Yes, would consider
# 2   4.9 5.7 6.5 7.5 67.1 No, would not consider
# 3   4.5 8.9 8.4 9.0 72.1 Yes, would consider
# 4   3.0 4.8 6.0 7.2 40.1 No, would not consider
# 5   3.5 7.1 6.6 9.0 57.1 No, would not consider
# 6   3.3 4.7 6.3 6.1 50.1 No, would not consider
# 7   2.0 5.7 7.8 7.2 41.1 No, would not consider
# 8   3.7 6.3 5.8 7.7 56.1 No, would not consider
# 9   4.6 7.0 7.5 8.2 56.1 Yes, would consider
# 10  4.4 5.5 5.9 6.7 59.1 No, would not consider
# 11  4.0 7.4 7.0 8.4 68.1 No, would not consider
# 12  3.2 6.0 6.3 6.6 53.1 No, would not consider
# 13  4.4 8.4 8.4 7.9 58.1 Yes, would consider
# 14  4.2 7.6 6.9 8.2 72.1 Yes, would consider
# 15  5.2 8.0 7.0 7.6 62.1 Yes, would consider
# 16  4.5 6.6 6.4 7.1 71.1 No, would not consider
# 17  4.5 6.4 7.5 7.2 50.1 Yes, would consider
# 18  4.8 7.4 6.9 8.2 58.1 Yes, would consider
# 19  4.5 6.8 7.5 7.9 55.1 No, would not consider
# 20  4.4 7.6 8.5 8.8 67.1 Yes, would consider
# 21  3.3 5.4 5.5 7.0 50.1 No, would not consider
# 22  4.3 9.9 9.6 9.9 70.1 Yes, would consider
# 23  4.0 7.0 7.1 8.1 60.1 No, would not consider
# 24  4.5 8.6 8.1 8.0 65.1 Yes, would consider
# 25  4.0 4.8 4.9 5.5 55.1 No, would not consider
# 26  3.9 6.6 6.8 7.0 58.1 No, would not consider
# 27  4.4 6.3 7.1 7.0 70.1 No, would not consider
# 28  3.7 5.4 5.5 5.6 55.1 No, would not consider
# 29  4.4 6.3 6.9 7.2 70.1 No, would not consider
# 30  3.5 5.4 5.5 6.2 52.1 No, would not consider
# ⋮   ⋮   ⋮   ⋮   ⋮   ⋮    ⋮
# 71  4.4 7.6 7.5 7.7 67.1 No, would not consider
# 72  3.1 5.8 6.0 7.0 43.1 No, would not consider
# 73  4.6 7.9 6.6 7.9 66.1 No, would not consider
# 74  3.9 8.6 8.8 9.8 66.1 Yes, would consider
# 75  3.7 8.2 7.0 8.4 65.1 Yes, would consider
# 76  3.8 7.1 6.6 8.9 63.1 Yes, would consider
# 77  3.9 6.4 6.9 7.5 49.1 No, would not consider
# 78  4.1 7.6 7.3 8.0 61.1 Yes, would consider
# 79  4.6 8.9 7.3 8.1 72.1 Yes, would consider
# 80  2.7 5.7 5.8 7.6 44.1 No, would not consider
# 81  3.8 7.1 7.9 8.8 63.1 No, would not consider
# 82  4.0 7.4 7.3 8.0 68.1 Yes, would consider
# 83  3.0 6.6 6.1 8.5 53.1 No, would not consider
# 84  1.6 5.0 5.1 6.5 37.1 No, would not consider
# 85  4.3 8.2 7.5 7.7 52.1 Yes, would consider
# 86  3.4 5.2 6.0 7.2 51.1 No, would not consider
# 87  3.1 5.2 5.5 6.0 48.1 No, would not consider
# 88  4.3 8.2 7.6 8.2 52.1 No, would not consider
# 89  3.9 7.3 6.5 7.4 59.1 No, would not consider
# 90  4.9 8.2 7.6 9.3 59.1 Yes, would consider
# 91  3.3 7.4 7.9 7.9 58.1 Yes, would consider
# 92  2.4 4.8 5.0 6.5 51.1 No, would not consider
# 93  4.2 7.6 7.5 8.6 72.1 No, would not consider
# 94  4.6 8.9 7.6 8.9 72.1 Yes, would consider
# 95  3.4 7.7 7.3 8.4 59.1 Yes, would consider
# 96  3.6 7.3 8.1 8.1 50.1 Yes, would consider
# 97  3.7 6.3 5.5 7.2 48.1 No, would not consider
# 98  2.5 5.4 7.0 7.7 51.1 No, would not consider
# 99  3.9 6.4 7.1 7.4 61.1 No, would not consider
# 100 3.5 6.4 7.3 7.0 57.1 No, would not consider

# %%
max = 10000
set.seed(123)

mse <- vector(length = max)
for(i in 1:max){
    indexTrain <- sample(1:nrow(hbat), 200, TRUE)
    indexTest  <- sample(1:nrow(hbat), 50, TRUE)

    train <- hbat[indexTrain, ]
    test <- hbat[indexTest, ]
    
    
    modelo <- lm(x19 ~ x7 + x9 + x11 + x12, train)
    y_predict <- predict(modelo, test[, c('x7', 'x9', 'x11', 'x12')])
    y_real <- hbat$x19[indexTest]
    
    mse[i] <- mean((y_real - y_predict)^2)
}

# %%
mean(mse)

# %%
sd(mse)

# %%
which.min(mse)
