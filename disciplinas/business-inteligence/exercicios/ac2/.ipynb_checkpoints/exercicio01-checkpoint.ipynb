# %% [markdown]
# # Exercicios KNN - Exercicio 1

# %% [markdown]
# Exercício 1.Desenvolver um modelo para prever se um carro apresenta um consumo alto ou baixo de combustível, utilizando a base de dados Auto.

# %% [markdown]
# ### Grupo

# %% [markdown]
# - Gabriel D. Padua RA 200749
# - Rafael Prestes RA 200779
# - Thomas Elinton RA 130531
# - Gabriela Fontolan RA 200645
# - Náthali Yukari RA 200145

# %%
library(ISLR)
library(FNN)

# %%
head(Auto)
# Out:
#   mpg cylinders displacement horsepower weight acceleration year origin
# 1 18  8         307          130        3504   12.0         70   1
# 2 15  8         350          165        3693   11.5         70   1
# 3 18  8         318          150        3436   11.0         70   1
# 4 16  8         304          150        3433   12.0         70   1
# 5 17  8         302          140        3449   10.5         70   1
# 6 15  8         429          198        4341   10.0         70   1
#   name
# 1 chevrolet chevelle malibu
# 2 buick skylark 320
# 3 plymouth satellite
# 4 amc rebel sst
# 5 ford torino
# 6 ford galaxie 500

# %%
mpg01 <- rep(0, nrow(Auto))

# %%
mpg01[Auto$mpg > median(Auto$mpg)] <- 1

# %%
Auto2 <- data.frame(Auto, mpg01)

# %%
head(Auto2)
# Out:
#   mpg cylinders displacement horsepower weight acceleration year origin
# 1 18  8         307          130        3504   12.0         70   1
# 2 15  8         350          165        3693   11.5         70   1
# 3 18  8         318          150        3436   11.0         70   1
# 4 16  8         304          150        3433   12.0         70   1
# 5 17  8         302          140        3449   10.5         70   1
# 6 15  8         429          198        4341   10.0         70   1
#   name                      mpg01
# 1 chevrolet chevelle malibu 0
# 2 buick skylark 320         0
# 3 plymouth satellite        0
# 4 amc rebel sst             0
# 5 ford torino               0
# 6 ford galaxie 500          0

# %%
set.seed(218)

# %%
nrow(Auto2)
# Out:
# [1] 392

# %% [markdown]
# ### Separando a base de dados - Treino

# %%
index <- sample(1:nrow(Auto2), nrow(Auto2) * 0.80)

# %%
train.x <- Auto2[index, c('cylinders', 'weight', 'displacement', 'horsepower')]

# %%
train.y <- Auto2[index, c('mpg01')]

# %% [markdown]
# ### Separando a base de dados - Teste

# %%
test.x <- Auto2[-index, c('cylinders', 'weight', 'displacement', 'horsepower')]

# %%
test.y <- Auto2[-index, c('mpg01')]

# %% [markdown]
# ## Rodando KNN - com k50

# %%
k <- 50
acurancy <- c('numeric', k);
precision <- c('numeric', k);
sensibility <- c('numeric', k);
f1score <- c('numeric', k);
especiality <- c('numeric', k);


for (i in 1:k) {
    knn.previsto <- knn(train.x, test.x, train.y, i);
    confusion <- table(test.y, knn.previsto);
    
    trueNegative <- confusion[1, 1];
    truePositive <- confusion[2, 2];
    falseNegative <- confusion[2, 1];
    falsePositive <- confusion[1, 2];
    
    acurancy[i] <- (trueNegative + truePositive) / (trueNegative + truePositive + falseNegative + falsePositive);
    precision[i] <- truePositive / (falsePositive + truePositive);
    sensibility[i] <- truePositive / (falseNegative + truePositive);
    especiality[i] <- trueNegative / (trueNegative + falsePositive);
    f1score[i] <- 2 * truePositive / (2*truePositive + falsePositive + falseNegative); 
}

# %% [markdown]
# ### Gráfico da acuracia

# %%
plot(acurancy, type='o')
# Out:
# plot without title

# %% [markdown]
# ### Modelo com maior acuracia

# %%
max(which(acurancy==max(acurancy)))
# Out:
# [1] 12

# %% [markdown]
# ### Gráfico da precisão

# %%
plot(precision, type='o')
# Out:
# plot without title

# %% [markdown]
# ### Modelo com maior precisão

# %%
max(which(precision==max(precision)))
# Out:
# [1] 12

# %% [markdown]
# ### Gráfico da sensibilidade

# %%
plot(sensibility, type='o')
# Out:
# plot without title

# %% [markdown]
# ### Modelo com menor sensibilidade

# %%
min(which(sensibility==min(sensibility)))
# Out:
# [1] 2

# %% [markdown]
# ### Modelo com maior sensibilidade

# %%
max(which(sensibility==max(sensibility)))
# Out:
# [1] 13

# %% [markdown]
# ### Gráfico F1 Score

# %%
plot(f1score, type='o');
# Out:
# plot without title

# %%
max(which(f1score==max(f1score)))
# Out:
# [1] 12

# %% [markdown]
# ### Gráfico da Especialidade

# %%
plot(especiality, type='o')
# Out:
# plot without title

# %% [markdown]
# ### Modelo com maior especialidade

# %%
max(which(especiality==max(especiality)))
# Out:
# [1] 12

# %% [markdown]
# ### Qual valor de K parece ter a melhor performance?

# %% [markdown]
# Segundo a analise das medidas a matriz de confusão e melhor modelo de K e o modelo k12
